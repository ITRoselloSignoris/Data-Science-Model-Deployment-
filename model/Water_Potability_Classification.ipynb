# %% [markdown]
# ## 0. Importar bibliotecas

# %%
import pandas as pd
import pickle
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from funpymodeling import status, freq_tbl

# %% [markdown]
# ## 1. Cargar datos

# %%
data = pd.read_csv("Dataset/water_potability.csv", sep=",")
data
# Out:
#             ph    Hardness        Solids  Chloramines     Sulfate  \
# 0          NaN  204.890455  20791.318981     7.300212  368.516441
# 1     3.716080  129.422921  18630.057858     6.635246         NaN
# 2     8.099124  224.236259  19909.541732     9.275884         NaN
# 3     8.316766  214.373394  22018.417441     8.059332  356.886136
# 4     9.092223  181.101509  17978.986339     6.546600  310.135738
# ...        ...         ...           ...          ...         ...
# 3271  4.668102  193.681735  47580.991603     7.166639  359.948574
# 3272  7.808856  193.553212  17329.802160     8.061362         NaN
# 3273  9.419510  175.762646  33155.578218     7.350233         NaN
# 3274  5.126763  230.603758  11983.869376     6.303357         NaN
# 3275  7.874671  195.102299  17404.177061     7.509306         NaN
#
#       Conductivity  Organic_carbon  Trihalomethanes  Turbidity  Potability
# 0       564.308654       10.379783        86.990970   2.963135           0
# 1       592.885359       15.180013        56.329076   4.500656           0
# 2       418.606213       16.868637        66.420093   3.055934           0
# 3       363.266516       18.436524       100.341674   4.628771           0
# 4       398.410813       11.558279        31.997993   4.075075           0
# ...            ...             ...              ...        ...         ...
# 3271    526.424171       13.894419        66.687695   4.435821           1
# 3272    392.449580       19.903225              NaN   2.798243           1
# 3273    432.044783       11.039070        69.845400   3.298875           1
# 3274    402.883113       11.168946        77.488213   4.708658           1
# 3275    327.459760       16.140368        78.698446   2.309149           1
#
# [3276 rows x 10 columns]

# %%
data.head(5)
# Out:
#          ph    Hardness        Solids  Chloramines     Sulfate  Conductivity  \
# 0       NaN  204.890455  20791.318981     7.300212  368.516441    564.308654
# 1  3.716080  129.422921  18630.057858     6.635246         NaN    592.885359
# 2  8.099124  224.236259  19909.541732     9.275884         NaN    418.606213
# 3  8.316766  214.373394  22018.417441     8.059332  356.886136    363.266516
# 4  9.092223  181.101509  17978.986339     6.546600  310.135738    398.410813
#
#    Organic_carbon  Trihalomethanes  Turbidity  Potability
# 0       10.379783        86.990970   2.963135           0
# 1       15.180013        56.329076   4.500656           0
# 2       16.868637        66.420093   3.055934           0
# 3       18.436524       100.341674   4.628771           0
# 4       11.558279        31.997993   4.075075           0

# %%
data.tail(5)
# Out:
#             ph    Hardness        Solids  Chloramines     Sulfate  \
# 3271  4.668102  193.681735  47580.991603     7.166639  359.948574
# 3272  7.808856  193.553212  17329.802160     8.061362         NaN
# 3273  9.419510  175.762646  33155.578218     7.350233         NaN
# 3274  5.126763  230.603758  11983.869376     6.303357         NaN
# 3275  7.874671  195.102299  17404.177061     7.509306         NaN
#
#       Conductivity  Organic_carbon  Trihalomethanes  Turbidity  Potability
# 3271    526.424171       13.894419        66.687695   4.435821           1
# 3272    392.449580       19.903225              NaN   2.798243           1
# 3273    432.044783       11.039070        69.845400   3.298875           1
# 3274    402.883113       11.168946        77.488213   4.708658           1
# 3275    327.459760       16.140368        78.698446   2.309149           1

# %%
status(data)
# Out:
#           variable  q_nan     p_nan  q_zeros   p_zeros  unique     type
# 0               ph    491  0.149878        1  0.000305    2785  float64
# 1         Hardness      0  0.000000        0  0.000000    3276  float64
# 2           Solids      0  0.000000        0  0.000000    3276  float64
# 3      Chloramines      0  0.000000        0  0.000000    3276  float64
# 4          Sulfate    781  0.238400        0  0.000000    2495  float64
# 5     Conductivity      0  0.000000        0  0.000000    3276  float64
# 6   Organic_carbon      0  0.000000        0  0.000000    3276  float64
# 7  Trihalomethanes    162  0.049451        0  0.000000    3114  float64
# 8        Turbidity      0  0.000000        0  0.000000    3276  float64
# 9       Potability      0  0.000000     1998  0.609890       2    int64

# %% [markdown]
# ## 2. Preparación de datos

# %%
data["ph"] , saved_bins1 = pd.qcut(data["ph"], retbins=True, q=5)
data["Trihalomethanes"] , saved_bins2 = pd.qcut(data["Trihalomethanes"], retbins=True, q=5)
data["Sulfate"] , saved_bins3 = pd.qcut(data["Sulfate"], retbins=True, q=5)

# %%
freq_tbl(data["ph"])
# Out:
#                 ph  frequency  percentage  cumulative_perc
# 0  (-0.001, 5.822]        557    0.170024              0.2
# 1   (5.822, 6.702]        557    0.170024              0.4
# 2   (6.702, 7.437]        557    0.170024              0.6
# 3   (7.437, 8.311]        557    0.170024              0.8
# 4    (8.311, 14.0]        557    0.170024              1.0

# %%
freq_tbl(data["Trihalomethanes"])
# Out:
#     Trihalomethanes  frequency  percentage  cumulative_perc
# 0   (0.737, 53.107]        623    0.190171         0.200064
# 1  (53.107, 62.656]        623    0.190171         0.400128
# 2  (70.446, 79.701]        623    0.190171         0.600193
# 3   (79.701, 124.0]        623    0.190171         0.800257
# 4  (62.656, 70.446]        622    0.189866         1.000000

# %%
data["ph"] = data["ph"].cat.add_categories("desconocido")
data["Trihalomethanes"] = data["Trihalomethanes"].cat.add_categories("desconocido")
data["Sulfate"] = data["Sulfate"].cat.add_categories("desconocido")

# %%
data["ph"] = data["ph"].fillna(value="desconocido")
data["Trihalomethanes"] = data["Trihalomethanes"].fillna(value="desconocido")
data["Sulfate"] = data["Sulfate"].fillna(value="desconocido")

# %%
freq_tbl(data["ph"])
# Out:
#                 ph  frequency  percentage  cumulative_perc
# 0  (-0.001, 5.822]        557    0.170024         0.170024
# 1   (5.822, 6.702]        557    0.170024         0.340049
# 2   (6.702, 7.437]        557    0.170024         0.510073
# 3   (7.437, 8.311]        557    0.170024         0.680098
# 4    (8.311, 14.0]        557    0.170024         0.850122
# 5      desconocido        491    0.149878         1.000000

# %%
data_ohe = pd.get_dummies(data)
data_ohe
# Out:
#         Hardness        Solids  Chloramines  Conductivity  Organic_carbon  \
# 0     204.890455  20791.318981     7.300212    564.308654       10.379783
# 1     129.422921  18630.057858     6.635246    592.885359       15.180013
# 2     224.236259  19909.541732     9.275884    418.606213       16.868637
# 3     214.373394  22018.417441     8.059332    363.266516       18.436524
# 4     181.101509  17978.986339     6.546600    398.410813       11.558279
# ...          ...           ...          ...           ...             ...
# 3271  193.681735  47580.991603     7.166639    526.424171       13.894419
# 3272  193.553212  17329.802160     8.061362    392.449580       19.903225
# 3273  175.762646  33155.578218     7.350233    432.044783       11.039070
# 3274  230.603758  11983.869376     6.303357    402.883113       11.168946
# 3275  195.102299  17404.177061     7.509306    327.459760       16.140368
#
#       Turbidity  Potability  ph_(-0.001, 5.822]  ph_(5.822, 6.702]  \
# 0      2.963135           0               False              False
# 1      4.500656           0                True              False
# 2      3.055934           0               False              False
# 3      4.628771           0               False              False
# 4      4.075075           0               False              False
# ...         ...         ...                 ...                ...
# 3271   4.435821           1                True              False
# 3272   2.798243           1               False              False
# 3273   3.298875           1               False              False
# 3274   4.708658           1                True              False
# 3275   2.309149           1               False              False
#
#       ph_(6.702, 7.437]  ...  Sulfate_(323.531, 342.095]  \
# 0                 False  ...                       False
# 1                 False  ...                       False
# 2                 False  ...                       False
# 3                 False  ...                       False
# 4                 False  ...                       False
# ...                 ...  ...                         ...
# 3271              False  ...                       False
# 3272              False  ...                       False
# 3273              False  ...                       False
# 3274              False  ...                       False
# 3275              False  ...                       False
#
#       Sulfate_(342.095, 367.369]  Sulfate_(367.369, 481.031]  \
# 0                          False                        True
# 1                          False                       False
# 2                          False                       False
# 3                           True                       False
# 4                          False                       False
# ...                          ...                         ...
# 3271                        True                       False
# 3272                       False                       False
# 3273                       False                       False
# 3274                       False                       False
# 3275                       False                       False
#
#       Sulfate_desconocido  Trihalomethanes_(0.737, 53.107]  \
# 0                   False                            False
# 1                    True                            False
# 2                    True                            False
# 3                   False                            False
# 4                   False                             True
# ...                   ...                              ...
# 3271                False                            False
# 3272                 True                            False
# 3273                 True                            False
# 3274                 True                            False
# 3275                 True                            False
#
#       Trihalomethanes_(53.107, 62.656]  Trihalomethanes_(62.656, 70.446]  \
# 0                                False                             False
# 1                                 True                             False
# 2                                False                              True
# 3                                False                             False
# 4                                False                             False
# ...                                ...                               ...
# 3271                             False                              True
# 3272                             False                             False
# 3273                             False                              True
# 3274                             False                             False
# 3275                             False                             False
#
#       Trihalomethanes_(70.446, 79.701]  Trihalomethanes_(79.701, 124.0]  \
# 0                                False                             True
# 1                                False                            False
# 2                                False                            False
# 3                                False                             True
# 4                                False                            False
# ...                                ...                              ...
# 3271                             False                            False
# 3272                             False                            False
# 3273                             False                            False
# 3274                              True                            False
# 3275                              True                            False
#
#       Trihalomethanes_desconocido
# 0                           False
# 1                           False
# 2                           False
# 3                           False
# 4                           False
# ...                           ...
# 3271                        False
# 3272                         True
# 3273                        False
# 3274                        False
# 3275                        False
#
# [3276 rows x 25 columns]

# %% [markdown]
# ## 3. Modelo de Clasificación

# %%
data_x = data_ohe.drop("Potability",axis=1)
data_y = data_ohe["Potability"]

# %%
x_train, x_test, y_train, y_test = train_test_split(data_x, data_y, test_size=0.3)

# %%
rf_model = RandomForestClassifier(n_estimators=1000, random_state=99)

# %%
rf_model.fit(x_train, y_train)
# Out:
# RandomForestClassifier(n_estimators=1000, random_state=99)

# %% [markdown]
# ## 4. Guardar modelo y columnas ohe

# %%
with open("categorias_ohe.pkl","wb") as handle:
    pickle.dump(data_x.columns, handle, protocol=pickle.HIGHEST_PROTOCOL)

# %%
pickle.dump(rf_model, open("rf.pkl", 'wb'))

# %%
rf_loaded = pickle.load(open("rf.pkl", 'rb'))
